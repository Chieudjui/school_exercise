# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Student = pd.read_csv("Student_data.csv")

# %%
Student
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
Student.mean()
# Out:
# StudentID            2196.500000
# Age                    16.468645
# Gender                  0.510870
# Ethnicity               0.877508
# ParentalEducation       1.746237
# StudyTimeWeekly         9.771992
# Absences               14.541388
# Tutoring                0.301421
# ParentalSupport         2.122074
# Extracurricular         0.383361
# Sports                  0.303512
# Music                   0.196906
# Volunteering            0.157191
# GPA                     1.906186
# GradeClass              2.983696
# dtype: float64

# %%
Student.median()
# Out:
# StudentID            2196.500000
# Age                    16.000000
# Gender                  1.000000
# Ethnicity               0.000000
# ParentalEducation       2.000000
# StudyTimeWeekly         9.705363
# Absences               15.000000
# Tutoring                0.000000
# ParentalSupport         2.000000
# Extracurricular         0.000000
# Sports                  0.000000
# Music                   0.000000
# Volunteering            0.000000
# GPA                     1.893393
# GradeClass              4.000000
# dtype: float64

# %%
Student.std()
# Out:
# StudentID            690.655244
# Age                    1.123798
# Gender                 0.499986
# Ethnicity              1.028476
# ParentalEducation      1.000411
# StudyTimeWeekly        5.652774
# Absences               8.467417
# Tutoring               0.458971
# ParentalSupport        1.122813
# Extracurricular        0.486307
# Sports                 0.459870
# Music                  0.397744
# Volunteering           0.364057
# GPA                    0.915156
# GradeClass             1.233908
# dtype: float64

# %%
Student.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
Student.isnull().count()
# Out:
# StudentID            2392
# Age                  2392
# Gender               2392
# Ethnicity            2392
# ParentalEducation    2392
# StudyTimeWeekly      2392
# Absences             2392
# Tutoring             2392
# ParentalSupport      2392
# Extracurricular      2392
# Sports               2392
# Music                2392
# Volunteering         2392
# GPA                  2392
# GradeClass           2392
# dtype: int64

# %%
Student_cor = np.corrcoef(Student["StudyTimeWeekly"], Student["GPA"])
Student_cor
# Out:
# array([[1.        , 0.17927513],
#        [0.17927513, 1.        ]])

# %%
Student_cor = np.corrcoef(Student["StudyTimeWeekly"], Student["GPA"])
f, ax = plt.subplots(figsize=(12, 9))
plt.title("Matrce de correlation entre Student StudyTimeWeekly et GPA")
sns.heatmap(Student_cor, square=True, annot = True);

# %%
Student_cor = Student.corr()
sns.heatmap(Student_cor, square=True, annot = True);

# %%
Studentheatmap = Student.drop(["StudentID"], axis = 1)
Studentheatmap = Studentheatmap.drop(["Gender"], axis = 1)
Studentheatmap = Studentheatmap.drop(["Sports"], axis = 1)
Studentheatmap = Studentheatmap.drop(["Age"], axis = 1)
Studentheatmap = Studentheatmap.drop(["Ethnicity"], axis = 1)
Studentheatmap = Studentheatmap.drop(["Volunteering"], axis = 1)

sns.heatmap(Studentheatmap.corr(), annot = True)
plt.figure(figsize = (50, 50))

# %%
plt.title("Comment les absences affectent-elles la performance des étudiants ?")
plt.bar(Student["Absences"], Student["GPA"])
plt.xlabel('Absences')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("Quel est l'impact du support parental sur les résultats académiques ?")
plt.bar(Student["ParentalSupport"], Student["GPA"])
plt.xlabel('ParentalSupport')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("L'engagement dans des activités hors cursus (sports, musique, volontariat) influence-t-il les notes ?")
plt.bar(Student["Music"], Student["GPA"])
plt.xlabel('Music')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("L'engagement dans des activités hors cursus (sports, musique, volontariat) influence-t-il les notes ?")
plt.bar(Student["Sports"], Student["GPA"], )
plt.xlabel('Sports')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("L'engagement dans des activités hors cursus (sports, musique, volontariat) influence-t-il les notes ?")
plt.bar(Student["Volunteering"], Student["GPA"])
plt.xlabel('Volunteering')
plt.ylabel('GPA')
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("Les performances varient-elles en fonction du genre ou de l'âge des étudiants ?")
sns.boxplot(x = Student["Age"], y = Student["GPA"], data = Student)
plt.xlabel('Age')
plt.ylabel('GPA')

#Vu le graph, les performances ne sont pas constant, Ce qui veux dire oui les performances des étudiants varient legèrement en fonction de l'age.
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("Les performances varient-elles en fonction du genre ou de l'âge des étudiants ?")
sns.boxplot(x = Student["Gender"], y = Student["GPA"], data = Student)
plt.xlabel('Gender')
plt.ylabel('GPA')

#Vu le graph, les performances ne sont constant, Ce qui veux dire non les performances des étudiants ne varient pas en fonction de l'age.
# Out:
# Text(0, 0.5, 'GPA')

# %%
plt.title("Le niveau d’éducation des parents a-t-il un effet sur les résultats scolaires ?")
plt.bar(Student["ParentalEducation"], Student["GPA"])
plt.xlabel('ParentalEducation')
plt.ylabel('GPA')

#Vu le graph, Le niveau d’éducation des parents a un effet sur les résultats scolaires . Ce qui veux dire oui.
# Out:
# Text(0, 0.5, 'GPA')

# %%
"""Prédiction des notes :
— Quels facteurs semblent être les meilleurs prédicteurs des notes finales ?
Pour ma part, je penses que ce sont: Absences, Volunteering, Sports, ParentalEducation, ParentalSupport.

— Comment pouvez-vous modéliser la performance des étudiants à partir des autres variables ?
Les méthodes de machine Learning peut etre utiliser, par example DecisionTreeRegressor, LinearRegression

— Quel(s) modèle(s) d apprentissage automatique pouvez-vous utiliser pour prédire les résultats
futurs des étudiants ?
K-Nearest Neighbors (K-NN)
Support Vector Machines (SVM)
"""
# Out:
# 'Prédiction des notes :\n— Quels facteurs semblent être les meilleurs prédicteurs des notes finales ?\nPour ma part, je penses que ce sont: Absences, Volunteering, Sports, ParentalEducation.\n\n— Comment pouvez-vous modéliser la performance des étudiants à partir des autres variables ?\nLes méthodes de machine Learning peut etre utiliser, par example DecisionTreeRegressor, LinearRegression\n\n— Quel(s) modèle(s) d apprentissage automatique pouvez-vous utiliser pour prédire les résultats\nfuturs des étudiants ?\nK-Nearest Neighbors (K-NN)\nSupport Vector Machines (SVM)\n'

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X1 = Student[["Absences"]]
y1 = Student["GPA"]

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y2_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y2_pred)
r2 = r2_score(y_test, y2_pred)




print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 0.12338466069228327
# R-squared: 0.8534682058290782

# %%
X = Student[['Absences', 'ParentalEducation', 'ParentalSupport', 'Volunteering', 'Sports', 'Music']]
y = Student['GPA']
X_train,X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
y_train.shape
# Out:
# (1674,)

# %%
y_test.shape
# Out:
# (718,)

# %%
model = linear_model.LinearRegression()
#Fitting the Multiple Linear Regression model
model = LinearRegression().fit(X_train, y_train)

#Printing the model coefficients
print('Intercept: ', model.intercept_)
# pair the feature names with the coefficients
list(zip(X, model.coef_))
# Out:
# Intercept:  2.9445933481352107
# [('Absences', -0.09909907938651373),
#  ('ParentalEducation', -0.0011106872913913546),
#  ('ParentalSupport', 0.15004657850492212),
#  ('Volunteering', -0.04450012527943346),
#  ('Sports', 0.20560235016176717),
#  ('Music', 0.15086505626241037)]

# %%
#Predicting the Test and Train set result 
y_pred= model.predict(X_test)  
x_pred= model.predict(X_train)

# %%
print("Prediction for test set: {}".format(y_pred))
# Out:
# Prediction for test set: [2.95161527 2.40374229 1.06651138 2.45328689 1.36151179 0.41674341
#  2.00401391 1.41164081 1.11895184 1.12174776 2.01112589 2.89701631
#  1.85507802 0.77239234 0.86519791 2.64618542 2.60194045 1.51677824
#  2.50284137 0.66448617 2.84495813 2.15517118 3.39110881 2.80643211
#  3.14336605 3.34324944 2.4496725  1.11516205 0.36468522 2.60444416
#  0.91392404 2.706084   2.50522827 1.41164081 1.75679742 3.15438464
#  1.11154765 1.55889147 1.56518497 2.80643211 1.26159423 1.41053012
#  3.14336605 2.4026316  3.09241855 3.09241855 0.96540768 3.39251171
#  0.97170118 3.24357582 2.40152092 1.81433063 2.60222278 0.77254621
#  0.66477838 1.21694024 3.39140102 2.84327289 0.72366621 2.24867842
#  1.90824689 0.9158532  1.21791258 2.35640919 1.85339279 0.72328394
#  1.31685779 3.20003251 1.21833326 2.44798726 0.56288338 2.75548461
#  2.69770747 2.70733303 1.45757101 2.55617577 2.25792171 2.10883195
#  1.36323408 2.21183764 0.97170118 2.69770747 0.92325739 0.8663086
# ...

# %%
#Actual value and the predicted value
model_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': y_pred})
model_diff
# Out:
#       Actual value  Predicted value
# 160       3.375994         2.951615
# 1740      2.777967         2.403742
# 1741      1.223828         1.066511
# 992       2.271400         2.453287
# 942       1.141639         1.361512
# ...            ...              ...
# 8         2.896819         3.306690
# 2241      1.761000         1.509629
# 512       3.149645         3.047918
# 1216      2.256488         2.005125
# 147       2.314588         2.509135
#
# [718 rows x 2 columns]

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', r2)
# Out:
# Mean Absolute Error: 0.24877397280930053
# Mean Square Error: 0.09187444840194371
# Root Mean Square Error: 0.30310798142236983

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(n_estimators=100, random_state=42)

rfr.fit(X_train, y_train)

y_pred_rfr = rfr.predict(X_test)

mae_rfr = mean_absolute_error(y_test, y_pred_rfr)
mse_rfr = mean_squared_error(y_test, y_pred_rfr)
r2_rfr = r2_score(y_test, y_pred_rfr)

print("Random Forest Mean Absolute Error:", mae_rfr)
print("Random Forest Mean Squared Error:", mse_rfr)
print("Random Forest R-squared:", r2_rfr)
# Out:
# Random Forest Mean Absolute Error: 0.27891896590139853
# Random Forest Mean Squared Error: 0.11762913942209771
# Random Forest R-squared: 0.861452484521215

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_pred, color='orange')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')
plt.title("Prédictions vs Valeurs réelles")
plt.ylabel("Prédictions")
plt.xlabel("Valeurs réelles")
plt.show()

# %%
"""
Conclusions et recommandations :
— Quels sont les principaux résultats obtenus à partir de votre analyse ?
[('Absences', -0.09985247701335068),
 ('ParentalEducation', -0.0006565974454022673),
 ('ParentalSupport', 0.15196583882342804),
 ('Volunteering', -0.03666663236414003),
 ('Sports', 0.17946423882547563),
 ('Music', 0.12657408054864103)]
Vu mon analyse, plusieur chose affecte positivement et négativement les resultats des élèves. 

— Que conseilleriez-vous à un étudiant, sur la base des résultats, pour améliorer ses performances ?
pour ma part, l élève ne dois pas manquer de cours, doit plus mettre son energie et temps sur ses études et non dans le voluntariat.
"""
# Out:
# "\nConclusions et recommandations :\n— Quels sont les principaux résultats obtenus à partir de votre analyse ?\n[('Absences', -0.09985247701335068),\n ('ParentalEducation', -0.0006565974454022673),\n ('ParentalSupport', 0.15196583882342804),\n ('Volunteering', -0.03666663236414003),\n ('Sports', 0.17946423882547563),\n ('Music', 0.12657408054864103)]\nVu mon analyse, plusieur chose affecte positivement et négativement les resultats des élèves. \n\n— Que conseilleriez-vous à un étudiant, sur la base des résultats, pour améliorer ses performances ?\npour ma part, l élève ne dois pas manquer de cours, doit plus mettre son energie et temps sur ses études et non dans le voluntariat.\n"

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
def chatbot():
    # Accueil et personnalisation
    print("Bonjour à vous ! Je suis ici pour vous aider à améliorer vos résultats académiques.")
    prenom = input("Comment vous appelez-vous ? ")
    print(f"Enchanté de faire votre connaissance, {prenom} ! Commençons par évaluer votre situation actuelle.")
# Fonction pour vérifier que l'entrée est un entier
    def demander_entier(question):
        while True:
            try:
                reponse = int(input(question))
                return reponse
            except ValueError:
                print("Veuillez entrer un nombre entier valide.")

    # Questions sur les performances académiques
    cours_manqués = demander_entier("Combien de cours avez-vous manqué ce semestre ? ")

    if cours_manqués >= 5:
        print("Il semble que vous ayez manqué plusieurs cours. Essayez de limiter les absences, cela pourrait avoir un impact positif sur vos résultats.")
    else:
        print("Bravo ! Vous semblez être très assidu en classe.")

    participation = demander_entier("À quel point participez-vous activement en classe sur une échelle de 1 à 5 ? ")

    if participation < 3:
        print("Vous avez mentionné que vous participez peu en classe. Augmenter votre participation peut vous aider à mieux comprendre les concepts et améliorer vos notes.")
    else:
        print("Excellent ! Votre participation active est un atout majeur pour votre apprentissage.")
        
    note_moyenne = demander_entier("Quelle est votre note moyenne jusqu'à présent ? ")

    if note_moyenne < 2:
        print("Vos résultats semblent un peu faibles. Je vous conseille de réviser les concepts fondamentaux et de participer aux séances de tutorat si possible.")
    elif 2 <= note_moyenne < 3:
        print("Votre note est correcte, mais il y a de la place pour l'amélioration. Un effort supplémentaire peut faire toute la différence.")
    else:
        print("Félicitations ! Vous avez de bons résultats. Continuez sur cette lancée.")

    # Organisation et gestion du temps
    heures_etudes_semaine = demander_entier("Combien d'heures par semaine consacrez-vous à l'étude en dehors des cours ? ")

    if heures_etudes_semaine >= 10:
        print("Parfait, vous avez l'air de bien gérer votre temps d'étude..")
    elif 5 <= heures_etudes_semaine < 10:
        print("C'est un bon début, mais viser au moins 10 heures pourrait vous être encore plus bénéfique.")
    else:
        print("Vous devriez augmenter le temps consacré à vos études. Il est recommandé d'y consacrer au moins 5 à 10 heures par semaine.")

    examen_revision_jours = demander_entier("Combien de jours à l'avance commencez-vous à réviser pour un examen important ? ")

    if examen_revision_jours > 3:
        print("Bien, parcequ'un bon planning de révision est essentiel pour réussir vos examens.")
    else:
        print("Si vous commencez à réviser trop tard, essayez d'établir un planning d'étude régulier pour être mieux préparé avant les examens.")

    # Questions supplémentaires
    niveau_de_stress = demander_entier("Comment évaluez-vous votre niveau de stress avant les examens sur une échelle de 1 à 5 ? ")

    if niveau_de_stress > 3:
        print("Un stress élevé avant les examens peut nuire à vos performances. Adoptez des techniques telles que la méditation ou la respiration profonde et le yoga.")
    else:
        print("Il est essentiel de maîtriser son stress. Vous êtes sur la bonne voie, continuez!")

    motivation_amélioration = demander_entier("À quel point êtes-vous motivé pour améliorer vos résultats cette année sur une échelle de 1 à 5 ? ")
    
    if motivation_amélioration < 3:
        print("Il semble que vous manquiez de motivation, c'est pas bon signe. Pour avançer faudra vous fixez des objectifs à court terme et célébrez chaque progrès pour rester sur la bonne voie.")
    else:
        print("C’est formidable de voir votre motivation ! Continuez à vous fixer des objectifs et à l’entretenir pour rester sur la bonne voie.")

    # Utilisation des ressources
    utilise_ressources = input("Utilisez-vous souvent les ressources académiques fournies par le professeur ou cherchez-vous des supports supplémentaires ailleurs (oui/non) ? ").lower()

    if utilise_ressources == "oui":
        print("Excellent ! Profitez de toutes les ressources à votre disposition, comme les bibliothèques et les plateformes en ligne.")
    else:
        print(input(f"Pourquoi {prenom}?"))
        print("Okay je comprends, mais n'hésitez pas à utiliser les ressources fournies par les enseignants et faites l'effort d'explorer d'autres supports pour compléter votre apprentissage.")

    # Conclusion personnalisée
    print(f"Merci pour ces informations, {prenom}. J'espère que ces conseils vous seront utiles. Si vous avez besoin de plus d'aide, n'hésitez pas à revenir vers moi !")

# Lancer le chatbot
chatbot()
# Out:
# Bonjour à vous ! Je suis ici pour vous aider à améliorer vos résultats académiques.
# Comment vous appelez-vous ?  Lae
# Enchanté de faire votre connaissance, Lae ! Commençons par évaluer votre situation actuelle.
# Combien de cours avez-vous manqué ce semestre ?  3
# Bravo ! Vous semblez être très assidu en classe.
# À quel point participez-vous activement en classe sur une échelle de 1 à 5 ?  4
# Excellent ! Votre participation active est un atout majeur pour votre apprentissage.
# Quelle est votre note moyenne jusqu'à présent ?  5
# Félicitations ! Vous avez de bons résultats. Continuez sur cette lancée.
# Combien d'heures par semaine consacrez-vous à l'étude en dehors des cours ?  4
# Vous devriez augmenter le temps consacré à vos études. Il est recommandé d'y consacrer au moins 5 à 10 heures par semaine.
# Combien de jours à l'avance commencez-vous à réviser pour un examen important ?  3
# ...
